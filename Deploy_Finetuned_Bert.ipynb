# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers

# %%
# !pip install huggingface_hub

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# %%
# Load the saved model from Google Drive
model = BertForSequenceClassification.from_pretrained('/content/drive/MyDrive/checkpoint-16830')

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
model.push_to_hub("yasamangs/FineTuneBert")
# Out:
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/yasamangs/FineTuneBert/commit/155b27ecf44917453b0be2fe1eddb571f3ea945c', commit_message='Upload BertForSequenceClassification', commit_description='', oid='155b27ecf44917453b0be2fe1eddb571f3ea945c', pr_url=None, repo_url=RepoUrl('https://huggingface.co/yasamangs/FineTuneBert', endpoint='https://huggingface.co', repo_type='model', repo_id='yasamangs/FineTuneBert'), pr_revision=None, pr_num=None)

# %%
model
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
model = BertForSequenceClassification.from_pretrained("yasamangs/FineTuneBert",use_auth_token='Use your own code')
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:3491: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
